# %% [markdown]
# # PCM-NO LC quick start
#
# This notebook installs the repository, checks the released data interface, and runs the smoke protocol. The smoke run is not used for paper results.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/yneversky/PCM-NO.git /content/PCM-NO
# %cd /content/PCM-NO
# !pip install -e .

# %%
# !python data/lc/download_lc.py --repo yneversky/PCM-NO

# %%
# !python scripts/train.py --config configs/lc_smoke.yaml --method pcmno --seed 0

# %%
# !python scripts/evaluate.py --config configs/lc_smoke.yaml --method pcmno --seed 0 --horizons 1 2 3
